# %%
What is the difference between Hardware and Software?Give one example each.

Hardware: It is an essential component of a computer which can physically touch.Ex: Monitor,cpu,RAM,Mouse etc.
Software: It Cannot touch physically,It is prepared using any of the programming language and runs on the OS.Ex: calculater,chrome etc
